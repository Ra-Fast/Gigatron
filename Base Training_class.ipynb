# %%
# Define parameters

# Seed
seed=123

# Samples
num_samples=10000
num_dimensions=3
num_classes=2

# Neural network
num_layers=1
num_neurons_per_layer=5
num_epochs = 200 
batch_size = 128    


# Import class
from model_reduction import ModelGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_8127/2997033170.py in <module>
#      17
#      18 # Import class
# ---> 19 from model_reduction import ModelGenerator
#
# ~/Documentos/Doctorado/Gigatron/model_reduction.py in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from sklearn.datasets import make_classification
#       4 from sklearn.preprocessing import MinMaxScaler
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Build model
model_instance = ModelGenerator(num_dimensions=num_dimensions, num_classes=num_classes, num_samples=num_samples, random_state=seed)
X, y = model_instance.generate_synthetic_data(plot_scatter=True)

# %%
# Data distribution
model_instance.plot_histogram(num_bins=20)

# %%
# Build neural network
model_instance.build_neural_network(num_layers, num_neurons_per_layer)
# Out:
# 2023-12-03 16:15:36.611158: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-03 16:15:36.620368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.620455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3050 Ti Laptop GPU computeCapability: 8.6
# coreClock: 1.485GHz coreCount: 20 deviceMemorySize: 3.81GiB deviceMemoryBandwidth: 178.84GiB/s
# 2023-12-03 16:15:36.620599: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-12-03 16:15:36.621440: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-12-03 16:15:36.622442: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-12-03 16:15:36.622631: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-12-03 16:15:36.623408: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-12-03 16:15:36.623759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-12-03 16:15:36.625267: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-03 16:15:36.625376: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.625493: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.625538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2023-12-03 16:15:36.625720: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2023-12-03 16:15:36.629814: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2688000000 Hz
# 2023-12-03 16:15:36.630469: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27392e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-03 16:15:36.630477: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-03 16:15:36.668286: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.668498: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x616b270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-03 16:15:36.668510: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Ti Laptop GPU, Compute Capability 8.6
# 2023-12-03 16:15:36.668653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.668736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3050 Ti Laptop GPU computeCapability: 8.6
# coreClock: 1.485GHz coreCount: 20 deviceMemorySize: 3.81GiB deviceMemoryBandwidth: 178.84GiB/s
# 2023-12-03 16:15:36.668764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-12-03 16:15:36.668771: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-12-03 16:15:36.668778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2023-12-03 16:15:36.668783: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2023-12-03 16:15:36.668789: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2023-12-03 16:15:36.668795: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2023-12-03 16:15:36.668800: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-12-03 16:15:36.668825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.668879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.668919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2023-12-03 16:15:36.668935: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2023-12-03 16:15:36.669055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-03 16:15:36.669058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2023-12-03 16:15:36.669060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2023-12-03 16:15:36.669095: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.669153: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-03 16:15:36.669211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3512 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3050 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 26
# Trainable params: 26
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_instance.train_neural_network(num_epochs=num_epochs,batch_size=batch_size)
# Out:
# 2023-12-03 16:15:37.417337: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# (      feature_0  feature_1  feature_2
#  9216   0.284286   0.756380   0.537730
#  7324   0.358322   0.344856   0.383884
#  918    0.335914   0.699165   0.459653
#  5902   0.284325   0.637930   0.500377
#  2807   0.322172   0.470942   0.547032
#  ...         ...        ...        ...
#  9785   0.428706   0.592327   0.419161
#  7763   0.290842   0.669754   0.557503
#  5218   0.392545   0.423136   0.590833
#  1346   0.572666   0.580343   0.524387
#  3582   0.504385   0.464769   0.402266
#
#  [8000 rows x 3 columns],
#        feature_0  feature_1  feature_2
#  2656   0.540137   0.442088   0.423031
#  445    0.619111   0.719173   0.514955
#  9505   0.602645   0.524882   0.448465
#  332    0.510702   0.726970   0.474586
#  4168   0.578660   0.816166   0.562510
#  ...         ...        ...        ...
#  8018   0.553262   0.615767   0.480749
#  6463   0.500805   0.316176   0.317840
#  2883   0.631299   0.468390   0.392233
#  7895   0.701894   0.606755   0.435375
#  620    0.285322   0.448551   0.750589
#
#  [2000 rows x 3 columns],
#  9216    1
#  7324    0
#  918     1
#  5902    1
#  2807    0
#         ..
#  9785    1
#  7763    1
#  5218    0
#  1346    0
#  3582    1
#  Name: target, Length: 8000, dtype: int64,
#  2656    1
#  445     1
#  9505    0
#  332     1
#  4168    1
#         ..
#  8018    1
#  6463    0
#  2883    0
#  7895    1
#  620     0
#  Name: target, Length: 2000, dtype: int64,
#  array([[0.20060499],
#         [0.99227905],
#         [0.6129376 ],
#         ...,
#         [0.32221672],
#         [0.913501  ],
#         [0.12725796]], dtype=float32),
#  array([[False],
#         [ True],
#         [ True],
#         ...,
#         [False],
#         [ True],
#         [False]]))

# %%
# Plot history
model_instance.plot_training_history()

# %%
model_instance.performance_measurement()
# Out:
# accuracy: 0.8955
# precision: 0.8827
# recall: 0.90705
# auc: 0.89574

# %%
model_instance.plot_confusion_matrix()

# %%
# Performance measurement - AUC
model_instance.plot_roc_curve()

# %%
model_instance.drop_fraction()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_excel("Final Result.xlsx")

# %%
data.head()
# Out:
#    reduction_x    entropy  relative_entropy  reduction_y  accuracy  precision  \
# 0            0  32.599944          0.000000            0   0.94230    0.92779
# 1           10  32.601256          0.002857           10   0.91194    0.90230
# 2           20  32.598606          0.007058           20   0.96700    0.95984
# 3           30  32.599146          0.013031           30   0.96214    0.95580
# 4           40  32.601781          0.023415           40   0.91983    0.90879
#
#     recall  auc_value  f1_score  epochs       time  time_per_epoch
# 0  0.95873    0.94237   0.94301     114  73.474807        0.644516
# 1  0.92441    0.91191   0.91322     100  68.896430        0.688964
# 2  0.97493    0.96698   0.96733     124  60.048804        0.484265
# 3  0.96917    0.96214   0.96244     144  75.419913        0.523749
# 4  0.93280    0.91987   0.92064     116  43.059937        0.371206

# %%
x=data['relative_entropy']
y=data['f1_score']
area=data['time_per_epoch']*100

plt.scatter(x,y,s=area)
plt.show()

# %%
sns.scatterplot(data=data,x='relative_entropy',y='f1_score',size='time_per_epoch',hue='entropy',legend='brief')
